# %%
import pyregions
from pprint import pprint
from functools import partial 
import os

pprint = partial(pprint, width = 180)

import pandas

test_data = """1900	1901	1902	1903	1904	1905	1906	1907	1908	1909	1910	1911	1912	1913	1914	1915	1916	1917	1918	1919	1920	1921	1922	1923	1924	1925	1926	1927	1928	1929	1930	1931	1932	1933	1934	1935	1936	1937	1938	1939	1940	1941	1942	1943	1944	1945	1946	1947	1948	1949	1950	1951	1952	1953	1954	1955	1956	1957	1958	1959	1960	1961	1962	1963	1964	1965	1966	1967	1968	1969	1970	1971	1972	1973	1974	1975	1976	1977	1978	1979	1980	1981	1982	1983	1984	1985	1986	1987	1988	1989	1990
76,094,000	77,585,000	79,160,000	80,632,000	82,165,000	83,820,000	85,437,000	87,000,000	88,709,000	90,492,000	92,407,000	93,868,000	95,331,000	97,227,000	99,118,000	100,549,000	101,966,000	103,266,000	103,203,000	104,512,000	106,466,000	108,541,000	110,055,000	111,950,000	114,113,000	115,832,000	117,399,000	119,038,000	120,501,000	121,770,000	123,077,000	124,040,000	124,840,000	125,579,000	126,374,000	127,250,000	128,053,000	128,825,000	129,825,000	130,880,000	131,954,000	133,121,000	133,920,000	134,245,000	132,885,000	132,481,000	140,054,000	143,446,000	146,093,000	148,665,000	151,868,000	153,982,000	156,393,000	158,956,000	161,884,000	165,069,000	168,088,000	171,187,000	174,149,000	177,135,000	179,975,000	182,973,000	185,738,000	188,438,000	191,085,000	193,460,000	195,501,000	197,374,000	199,312,000	201,306,000	203302031	206827026	209283905	211357481	213341554	215465255	217562735	219759869	222095080	224567241	226545805	229465714	231664458	233791994	235824902	237923795	240132887	242288918	244498982	246819230	248709873"""

years, values = test_data.split("\n") 
years = [i+"-01-01" for i in years.split("\t")]
values = [int(i.replace(',', '')) for i in values.split("\t")]
index = pandas.date_range('1/1/1900', periods=len(years), freq='Y')
#test_data = [(i, j) for i,j in zip(years, values)]
test_data = pandas.Series(values, index = years)
test_data.dt.date
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\tseries\frequencies.py in get_offset(name)
#     623             split = name.split('-')
# --> 624             klass = prefix_mapping[split[0]]
#     625             # handles case where there's no suffix (and will TypeError if too
#
# KeyError: 'Y'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\tseries\frequencies.py in to_offset(freq)
#     549                 stride = int(stride)
# --> 550                 offset = get_offset(name)
#     551                 offset = offset * int(np.fabs(stride) * stride_sign)
#
# ~\Anaconda3\lib\site-packages\pandas\tseries\frequencies.py in get_offset(name)
#     629             # bad prefix or suffix
# ...

# %%
test_data.resample('YS')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\tseries\frequencies.py in get_offset(name)
#     623             split = name.split('-')
# --> 624             klass = prefix_mapping[split[0]]
#     625             # handles case where there's no suffix (and will TypeError if too
#
# KeyError: 'YS'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\tseries\frequencies.py in to_offset(freq)
#     549                 stride = int(stride)
# --> 550                 offset = get_offset(name)
#     551                 offset = offset * int(np.fabs(stride) * stride_sign)
#
# ~\Anaconda3\lib\site-packages\pandas\tseries\frequencies.py in get_offset(name)
#     629             # bad prefix or suffix
# ...

# %%
package.widgets.importIsoNamespace()
# Out:
# {'namespace': {'code': 'ISO',
#   'name': 'International Organization for Standardization',
#   'regex': '(?P<iso2>[A-Z]{2})|(?P<iso3>[A-Z]{3})|(?P<numeric>[0-9]{3})',
#   'subtypes': 'iso2|iso3|numeric',
#   'url': 'https://www.iso.org/iso-3166-country-codes.html'},
#  'regions': [{'code': 'AFG',
#    'identifiers': ['AF', 'AFG', '004'],
#    'name': 'Afghanistan',
#    'regionType': 'country'},
#   {'code': 'ALB',
#    'identifiers': ['AL', 'ALB', '008'],
#    'name': 'Albania',
#    'regionType': 'country'},
#   {'code': 'DZA',
#    'identifiers': ['DZ', 'DZA', '012'],
#    'name': 'Algeria',
#    'regionType': 'country'},
#   {'code': 'ASM',
#    'identifiers': ['AS', 'ASM', '016'],
#    'name': 'American Samoa',
#    'regionType': 'country'},
#   {'code': 'AND',
#    'identifiers': ['AD', 'AND', '020'],
#    'name': 'Andorra',
#    'regionType': 'country'},
#   {'code': 'AGO',
#    'identifiers': ['AO', 'AGO', '024'],
#    'name': 'Angola',
#    'regionType': 'country'},
# ...
